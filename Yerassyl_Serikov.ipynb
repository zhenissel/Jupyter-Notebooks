# %% [markdown]
# <a href="https://colab.research.google.com/github/zhenissel/Jupyter-Notebooks/blob/main/Yerassyl_Serikov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Yerassyl Serikov**
# AI student

# %% [markdown]
# *I want to improve my skills in working with data and understand how to use statistics and programming to solve real problems.*

# %% [markdown]
# ### This code prints a short introduction and a small table

# %%
import pandas as pd

def introduce(name: str, role: str) -> str:
    return f"Hello, my name is {name} and I am a {role}."

name = "Yerassyl Serikov"
role = "AI student"

intro_message = introduce(name, role)
print(intro_message)
print()

skills_data = {
    "Skill": ["Python", "Statistics", "Data Analysis"],
    "Level": ["Beginner", "Improving", "Learning"]
}

skills_df = pd.DataFrame(skills_data)

print("Small snapshot of my current skills:")
print(skills_df)
# Out:
# Hello, my name is Yerassyl Serikov and I am a AI student.
#
# Small snapshot of my current skills:
#            Skill      Level
# 0         Python   Beginner
# 1     Statistics  Improving
# 2  Data Analysis   Learning

# %% [markdown]
# ---
#
# Here are some notes about how I work with code:
#
# - I like to test ideas in small steps.
# - I keep the output simple and readable.
# - I re-run cells to check results.
#
# 1. Start with a question
# 2. Write a small code example
# 3. Look at the output and continue learning
#
# Example experiment:
#
# ```python
# nums = [1, 2, 3]
# squares = [n*n for n in nums]
# print("Squares:", squares)
# ```
#
# More info about notebooks:
# [Jupyter Official Website](https://jupyter.org/)
